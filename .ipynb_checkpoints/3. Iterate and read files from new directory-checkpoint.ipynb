# %%
import os
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np


directory = '/Users/chung/Desktop/SaveSpace/Docs/'     #  <--- Put in here directory !!!!

master_list = []

for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        f = open(directory + filename)
        lines = f.read()
        html = BeautifulSoup(lines, "html.parser")
        
        job_page_item_list = []
        
        # ListItems
        publish_date = html.find(class_="jobsearch-JobMetadataFooter").get_text()
        job_page_item_list.append(publish_date)

        company = html.find(class_="icl-u-lg-mr--sm icl-u-xs-mr--xs").get_text()
        job_page_item_list.append(company)

        title = html.find("title").get_text()
        job_page_item_list.append(title)

        job_description_text = html.find(id="jobDescriptionText").get_text()

        word_count = len(job_description_text)
        job_page_item_list.append(word_count)
        #jobPageItemList.append(url)

        # Add jobPageItemList to masterList
        master_list.append(job_page_item_list)
        
        print (job_page_item_list)

df0 = pd.DataFrame(np.array(master_list),
           columns=['Date', 'Company', 'JobTitle', 'Wordcount'])    # <---- ADD URL TO THAT

df0


# TO DO 
# Clean Date column
# ADD url to data frame
# Out:
# ['Handelsblatt Media Group - vor 2 Stunden - speichern - Diesen Job melden - Originaljob', 'planet c GmbH', 'Junior Online Redakteur (w/m/d) - Hamburg - Indeed.com', 2766]
# ['Olympus Europa SE & Co. KG - vor 30+ Tagen - speichern - Diesen Job melden - Originaljob', 'Olympus Europa SE & Co. KG', 'Mitarbeiter/in in der Fertigung - Hamburg - Indeed.com', 55]
# ['BARMER - vor 2 Stunden - speichern - Diesen Job melden', 'BARMER', 'Jurist - Hamburg - Indeed.com', 1444]
# ['Meyer Werft - vor 30+ Tagen - speichern - Diesen Job melden - Originaljob', 'MAC Hamburg GmbH', 'Projektkoordinator Materialwirtschaft (m/w) für den Standort Hamburg - 22041 Hamburg - Indeed.com', 1689]
# ['flaschenpost SE - vor 30 Tagen - speichern - Diesen Job melden - Originaljob', 'flaschenpost SE', 'Auslieferungsfahrer (m/w/d) - Hamburg - Indeed.com', 1875]
# ['vor 3 Stunden - speichern - Diesen Job melden', 'Kälte-Klima24 GmbH', 'Kältetechnik kaufmännischer Projektleiter - Hamburg - Indeed.com', 3069]
# ['vor 3 Stunden - speichern', 'Kälte-Klima24 GmbH', 'Technischer Vertrieb Kältetechnik Lüftungstechnik Klimatechnik - Hamburg - Indeed.com', 3064]
# ['HOGAPAGE.de - vor 5 Stunden - speichern - Diesen Job melden - Originaljob', 'mama Restaurants GmbH', 'Restaurantleitung in Hamburg - 20148 Hamburg - Indeed.com', 2031]
# ['ANMATHO AG - vor 5 Stunden - speichern - Diesen Job melden', 'ANMATHO AG', 'Schulungsprofi im Bereich Informationssicherheit und Datenschutz (m/w) - Hamburg - Indeed.com', 3173]
# ['Klassik Radio - vor 3 Stunden - speichern - Diesen Job melden', 'Klassik Radio', 'Werkstudenten (m/w/d) mit guter Telefonstimme - Hamburg - Indeed.com', 1535]
# ['Carnival Maritime GmbH - vor 1 Stunde - speichern - Diesen Job melden - Originaljob', 'Carnival Maritime GmbH', 'Electrician Officer on Board (m/f/d) - Hamburg - Indeed.com', 1562]
# ['Handelsblatt Media Group - vor 2 Stunden - speichern - Diesen Job melden - Originaljob', 'iq digital media marketing gmbh', 'Studentische Aushilfe (w/m/d) im Bereich Sales Digital - Hamburg - Indeed.com', 1924]
# ['Hamburger Hochbahn - vor 30 Tagen - speichern - Diesen Job melden - Originaljob', 'Hamburger Hochbahn', 'Sachbearbeiterin / Sachbearbeiter Datenanalyse Fahrgastzählsysteme in Teilzeit (ca. 30 Std./Woche) - Hamburg - Indeed.com', 1587]
# ['ANMATHO AG - vor 5 Stunden - speichern - Diesen Job melden', 'ANMATHO AG', 'Berater Datenschutz (m/w) - Hamburg - Indeed.com', 3442]
# ['Hamburger Hochbahn - vor 30 Tagen - speichern - Diesen Job melden - Originaljob', 'Hamburger Hochbahn', 'Sachbearbeiterin / Sachbearbeiter Datenanalyse Fahrgastzählsysteme in Teilzeit (ca. 30 Std./Woche) - Hamburg - Indeed.com', 1587]
# ['HOGAPAGE.de - vor 5 Stunden - speichern - Diesen Job melden - Originaljob', 'Restaurant Zur Kastanie', 'Servicekraft/Kellner m/w/d - 22397 Hamburg - Indeed.com', 1199]
# ['flaschenpost SE - vor 30 Tagen - speichern - Diesen Job melden - Originaljob', 'flaschenpost SE', 'Auslieferungsfahrer (m/w/d) - Hamburg - Indeed.com', 1875]
# ['Meyer Werft - vor 30+ Tagen - speichern - Diesen Job melden - Originaljob', 'MAC Hamburg GmbH', 'Projektkoordinator Materialwirtschaft (m/w) für den Standort Hamburg - 22041 Hamburg - Indeed.com', 1689]
# ['vor 9 Stunden - speichern', 'Nutso Nuts Kernels GmbH', 'Vertriebsmitarbeiter (m/w) - Hamburg - Indeed.com', 574]
# ['DCI Digital Career Institute - vor 8 Stunden - speichern - Diesen Job melden - Originaljob', 'DCI Digital Career Institute', 'Bildungsberater (m/w/d) in Hamburg - 20099 Hamburg - Indeed.com', 2430]
# ['Airbus - vor 11 Stunden - speichern - Diesen Job melden - Originaljob', 'Airbus', 'Network Security Technology Specialist (d//f/m) - Hamburg - Indeed.com', 4175]
# ['Honeywell - vor 8 Stunden - speichern - Diesen Job melden - Originaljob', 'Honeywell', 'VDGS Solution Advisor - 22453 Hamburg - Indeed.com', 2525]
# ['F. REYHER Nchfg. GmbH & Co. KG - vor 2 Tagen - speichern - Diesen Job melden - Originaljob', 'F. REYHER Nchfg. GmbH & Co. KG', 'Mitarbeiter (m/w/d) Vertrieb Innendienst - Industrie Großkunden - 22769 Hamburg - Indeed.com', 1515]
# ['vor 30+ Tagen - speichern - Diesen Job melden', 'Nike Hamburg', 'NIKE VERKÄUFER (M/W/D) IN TEILZEIT 30H/WOCHE - 20095 Hamburg - Indeed.com', 1951]
# ['vor 6 Stunden - speichern - Diesen Job melden', 'Hauschildt & Blunck Wach- und Objektschutz GmbH & Co. KG / Personaldienstleistungen', 'Empfangskraft m/w 31h/Woche - Hamburg-Harburg - Indeed.com', 2094]
# 5                                  Kälte-Klima24 GmbH
# 6                                  Kälte-Klima24 GmbH
# 7                               mama Restaurants GmbH
# 8                                          ANMATHO AG
# 9                                       Klassik Radio
# 10                             Carnival Maritime GmbH
# 11                    iq digital media marketing gmbh
# 12                                 Hamburger Hochbahn
# 13                                         ANMATHO AG
# 14                                 Hamburger Hochbahn
# 15                            Restaurant Zur Kastanie
# 16                                    flaschenpost SE
# 17                                   MAC Hamburg GmbH
# 18                            Nutso Nuts Kernels GmbH
# 19                       DCI Digital Career Institute
# 20                                             Airbus
# 21                                          Honeywell
# 22                     F. REYHER Nchfg. GmbH & Co. KG
# 23                                       Nike Hamburg
# 24  Hauschildt & Blunck Wach- und Objektschutz Gmb...
# 25                                      Deutsche Bahn
# 26                                         ANMATHO AG
# 27                       Richter Premium Hotelservice
# 28                                       AMADEUS FIRE
# 29                                         ANMATHO AG
#
#                                              JobTitle Wordcount
# 0   Junior Online Redakteur (w/m/d) - Hamburg - In...      2766
# 1   Mitarbeiter/in in der Fertigung - Hamburg - In...        55
# 2                       Jurist - Hamburg - Indeed.com      1444
# 3   Projektkoordinator Materialwirtschaft (m/w) fü...      1689
# 4   Auslieferungsfahrer (m/w/d) - Hamburg - Indeed...      1875
# 5   Kältetechnik kaufmännischer Projektleiter - Ha...      3069
# 6   Technischer Vertrieb Kältetechnik Lüftungstech...      3064
# 7   Restaurantleitung in Hamburg - 20148 Hamburg -...      2031
# 8   Schulungsprofi im Bereich Informationssicherhe...      3173
# 9   Werkstudenten (m/w/d) mit guter Telefonstimme ...      1535
# 10  Electrician Officer on Board (m/f/d) - Hamburg...      1562
# 11  Studentische Aushilfe (w/m/d) im Bereich Sales...      1924
# 12  Sachbearbeiterin / Sachbearbeiter Datenanalyse...      1587
# 13   Berater Datenschutz (m/w) - Hamburg - Indeed.com      3442
# 14  Sachbearbeiterin / Sachbearbeiter Datenanalyse...      1587
# 15  Servicekraft/Kellner m/w/d - 22397 Hamburg - I...      1199
# 16  Auslieferungsfahrer (m/w/d) - Hamburg - Indeed...      1875
# 17  Projektkoordinator Materialwirtschaft (m/w) fü...      1689
# 18  Vertriebsmitarbeiter (m/w) - Hamburg - Indeed.com       574
# 19  Bildungsberater (m/w/d) in Hamburg - 20099 Ham...      2430
# 20  Network Security Technology Specialist (d//f/m...      4175
# 21  VDGS Solution Advisor - 22453 Hamburg - Indeed...      2525
# 22  Mitarbeiter (m/w/d) Vertrieb Innendienst - Ind...      1515
# 23  NIKE VERKÄUFER (M/W/D) IN TEILZEIT 30H/WOCHE -...      1951
# 24  Empfangskraft m/w 31h/Woche - Hamburg-Harburg ...      2094
# 25      Sachbearbeiter (w/m/d) - Hamburg - Indeed.com      1119
# 26  Junior Berater Informationssicherheit (m/w) - ...      3549
# 27  Mitarbeiter für allgemeine Büro-und Verwaltung...      1250
# 28  Senior Produktionscontroller (m/w/d) - Hamburg...      2280
# 29  Berater Informationssicherheit (m/w) - Hamburg...      3697
